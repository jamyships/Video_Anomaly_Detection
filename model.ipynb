# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nikanvasei/traffic-anomaly-dataset-tad")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\backupadmin\.cache\kagglehub\datasets\nikanvasei\traffic-anomaly-dataset-tad\1.archive...
# 100%|██████████| 12.5G/12.5G [21:10<00:00, 10.5MB/s]
# Extracting files...
# Path to dataset files: C:\Users\backupadmin\.cache\kagglehub\datasets\nikanvasei\traffic-anomaly-dataset-tad\versions\1
